# %% [markdown]
# ## mini project

# %% [markdown]
# ## load data from s3

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://fruit01/Fruit-Prices-2022.csv') 
df.head()
# Out:
#                         Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                      Apples   Fresh       1.8541       per pound   0.90
# 1          Apples, applesauce  Canned       1.1705       per pound   1.00
# 2      Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3  Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                    Apricots   Fresh       3.6162       per pound   0.93
#
#    CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0             0.2425            pounds              0.4996
# 1             0.5401            pounds              0.6323
# 2             8.0000      fluid ounces              0.4349
# 3             8.0000      fluid ounces              0.3043
# 4             0.3638            pounds              1.4145

# %% [markdown]
# ## view data

# %%
df.shape
# Out:
# (62, 8)

# %%
df['Yield']
# Out:
# 0     0.90
# 1     1.00
# 2     1.00
# 3     1.00
# 4     0.93
#       ...
# 57    0.96
# 58    1.00
# 59    0.94
# 60    1.00
# 61    0.52
# Name: Yield, Length: 62, dtype: float64

# %%
df.sort_values (by='RetailPrice')
# Out:
#                             Fruit   Form  RetailPrice RetailPriceUnit  Yield  \
# 61                     Watermelon  Fresh       0.3820       per pound   0.52
# 8                         Bananas  Fresh       0.5971       per pound   0.64
# 3      Apples, frozen concentrate  Juice       0.6086        per pint   1.00
# 46                      Pineapple  Fresh       0.6170       per pound   0.51
# 51  Pineapple, frozen concentrate  Juice       0.7256        per pint   1.00
# ..                            ...    ...          ...             ...    ...
# 20                           Figs  Dried       7.3233       per pound   0.96
# 38                         Papaya  Dried       7.4854       per pound   1.00
# 7                        Apricots  Dried       7.6611       per pound   1.00
# 57                    Raspberries  Fresh       7.7338       per pound   0.96
# 32                        Mangoes  Dried      10.3035       per pound   1.00
#
# ...

# %%
df[0:5]
# Out:
#                         Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                      Apples   Fresh       1.8541       per pound   0.90
# 1          Apples, applesauce  Canned       1.1705       per pound   1.00
# 2      Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3  Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                    Apricots   Fresh       3.6162       per pound   0.93
#
#    CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0             0.2425            pounds              0.4996
# 1             0.5401            pounds              0.6323
# 2             8.0000      fluid ounces              0.4349
# 3             8.0000      fluid ounces              0.3043
# 4             0.3638            pounds              1.4145

# %%
df[df['RetailPrice']>5]
# Out:
#                                  Fruit    Form  RetailPrice RetailPriceUnit  \
# 7                             Apricots   Dried       7.6611       per pound
# 10                        Blackberries   Fresh       6.7483       per pound
# 16  Cherries, packed in syrup or water  Canned       5.2418       per pound
# 18                         Cranberries   Dried       5.0828       per pound
# 19                               Dates   Dried       5.7499       per pound
# 20                                Figs   Dried       7.3233       per pound
# 32                             Mangoes   Dried      10.3035       per pound
# 38                              Papaya   Dried       7.4854       per pound
# 49                           Pineapple   Dried       7.0133       per pound
# 53                       Plum (prunes)   Dried       6.3293       per pound
# 57                         Raspberries   Fresh       7.7338       per pound
# ...

# %% [markdown]
# ## explore and clean data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Fruit               62 non-null     object
#  1   Form                62 non-null     object
#  2   RetailPrice         62 non-null     float64
#  3   RetailPriceUnit     62 non-null     object
#  4   Yield               62 non-null     float64
#  5   CupEquivalentSize   62 non-null     float64
#  6   CupEquivalentUnit   62 non-null     object
#  7   CupEquivalentPrice  62 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 4.0+ KB

# %%
df = df.rename(columns={"CupEquivalentSize": "CES", "CupEquivalentUnit": "CEU", "CupEquivalentPrice": "CEP"})
df.head()
# Out:
#                         Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                      Apples   Fresh       1.8541       per pound   0.90
# 1          Apples, applesauce  Canned       1.1705       per pound   1.00
# 2      Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3  Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                    Apricots   Fresh       3.6162       per pound   0.93
#
#       CES           CEU     CEP
# 0  0.2425        pounds  0.4996
# 1  0.5401        pounds  0.6323
# 2  8.0000  fluid ounces  0.4349
# 3  8.0000  fluid ounces  0.3043
# 4  0.3638        pounds  1.4145

# %%
df.isnull().sum()
# Out:
# Fruit              0
# Form               0
# RetailPrice        0
# RetailPriceUnit    0
# Yield              0
# CES                0
# CEU                0
# CEP                0
# dtype: int64

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Fruit              0
# Form               0
# RetailPrice        0
# RetailPriceUnit    0
# Yield              0
# CES                0
# CEU                0
# CEP                0
# dtype: int64

# %%
df.describe()
# Out:
#        RetailPrice      Yield        CES        CEP
# count    62.000000  62.000000  62.000000  62.000000
# mean      2.994571   0.876129   1.704984   1.065056
# std       2.269393   0.174979   2.949262   0.578325
# min       0.382000   0.460000   0.123200   0.242900
# 25%       1.364225   0.722500   0.322450   0.639300
# 50%       2.159250   0.980000   0.363800   1.008250
# 75%       4.116525   1.000000   0.540100   1.353475
# max      10.303500   1.000000   8.000000   3.555800

# %%
df=df[ (df['RetailPrice']>=0) & (df['Yield']>=0) & (df['CES']>=0) ]
df.describe()
# Out:
#        RetailPrice      Yield        CES        CEP
# count    62.000000  62.000000  62.000000  62.000000
# mean      2.994571   0.876129   1.704984   1.065056
# std       2.269393   0.174979   2.949262   0.578325
# min       0.382000   0.460000   0.123200   0.242900
# 25%       1.364225   0.722500   0.322450   0.639300
# 50%       2.159250   0.980000   0.363800   1.008250
# 75%       4.116525   1.000000   0.540100   1.353475
# max      10.303500   1.000000   8.000000   3.555800

# %%
df['Fruit'].value_counts()
# Out:
# Papaya                                      2
# Blackberries                                2
# Mangoes                                     2
# Peaches                                     2
# Blueberries                                 2
# Pineapple                                   2
# Apricots                                    2
# Raspberries                                 2
# Strawberries                                2
# Oranges, ready-to-drink                     1
# Oranges, frozen concentrate                 1
# Pears, packed in juice                      1
# Oranges                                     1
# Peaches, packed in juice                    1
# Peaches, packed in syrup or water           1
# Pears                                       1
# Apples                                      1
# Pineapple, packed in syrup or water         1
# Pears, packed in syrup or water             1
# Pineapple, packed in juice                  1
# ...

# %%
df = df [['Fruit', 'CEP', 'Yield', 'RetailPrice', 'CES']]
df.head()
# Out:
#                         Fruit     CEP  Yield  RetailPrice     CES
# 0                      Apples  0.4996   0.90       1.8541  0.2425
# 1          Apples, applesauce  0.6323   1.00       1.1705  0.5401
# 2      Apples, ready-to-drink  0.4349   1.00       0.8699  8.0000
# 3  Apples, frozen concentrate  0.3043   1.00       0.6086  8.0000
# 4                    Apricots  1.4145   0.93       3.6162  0.3638

# %%
df.set_index('Fruit', inplace = True)
df.head()
# Out:
#                                CEP  Yield  RetailPrice     CES
# Fruit
# Apples                      0.4996   0.90       1.8541  0.2425
# Apples, applesauce          0.6323   1.00       1.1705  0.5401
# Apples, ready-to-drink      0.4349   1.00       0.8699  8.0000
# Apples, frozen concentrate  0.3043   1.00       0.6086  8.0000
# Apricots                    1.4145   0.93       3.6162  0.3638

# %%
df.loc['Mangoes']
# Out:
#             CEP  Yield  RetailPrice     CES
# Fruit
# Mangoes  0.7531   0.71       1.4698  0.3638
# Mangoes  1.2906   1.00      10.3035  0.1253

# %%
df.to_csv('clean_fruit.csv')

# %% [markdown]
# ## visualize data

# %% [markdown]
# ## price ratio between yield and retail price

# %%
df.hist(layout=(2,2), figsize=(10,5), sharey=False, sharex=False, bins=50)
# Out:
# array([[<Axes: title={'center': 'CEP'}>,
#         <Axes: title={'center': 'Yield'}>],
#        [<Axes: title={'center': 'RetailPrice'}>,
#         <Axes: title={'center': 'CES'}>]], dtype=object)

# %%
sum_RetailPrice_by_Yield = df.groupby('Yield')['RetailPrice'].sum()
sum_RetailPrice_by_Yield.head()
# Out:
# Yield
# 0.46    1.1589
# 0.49    1.4444
# 0.51    1.3693
# 0.52    0.3820
# 0.56    2.4672
# Name: RetailPrice, dtype: float64

# %%
sum_RetailPrice_by_Yield.plot()
# Out:
# <Axes: xlabel='Yield'>

# %% [markdown]
# ## what fruit is the most expensive

# %%
sum_Fruit_by_RetailPrice = df.groupby('Fruit')['RetailPrice']
sum_Fruit_by_RetailPrice.nlargest(5).plot.bar()
# Out:
# <Axes: xlabel='Fruit,Fruit'>

# %% [markdown]
# ## what fruit is cheapest

# %%
sum_Fruit_by_RetailPrice = df.groupby('Fruit')['RetailPrice']
sum_Fruit_by_RetailPrice.nsmallest(5).plot.bar()
# Out:
# <Axes: xlabel='Fruit,Fruit'>

# %% [markdown]
# ## LAB 6

# %%
pip install jupyter-ai~=1.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter-ai[all]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
from botocore.exceptions import ClientError
import json

def get_secret(secret_name):
    region_name = "us-east-1"

    # Create a Secrets Manager client
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name
    )

    try:
        get_secret_value_response = client.get_secret_value(
            SecretId=secret_name
        )
    except ClientError as e:
        raise e

    secret = get_secret_value_response['SecretString']
    
    return json.loads(secret)

# %%
import os
os.environ["OPENAI_API_KEY"] = get_secret('openai')['api_key']

# %%
# %load_ext jupyter_ai_magics
# Out:
# The jupyter_ai_magics extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai_magics

# %%
# %ai list
# Out:
# ai21
# Requires environment variable: AI21_API_KEY (not set)
# * ai21:j1-large
# * ai21:j1-grande
# * ai21:j1-jumbo
# * ai21:j1-grande-instruct
# * ai21:j2-large
# * ai21:j2-grande
# * ai21:j2-jumbo
# * ai21:j2-grande-instruct
# * ai21:j2-jumbo-instruct
#
# bedrock
# * bedrock:amazon.titan-text-express-v1
# * bedrock:amazon.titan-text-lite-v1
# * bedrock:amazon.titan-text-premier-v1:0
# * bedrock:ai21.j2-ultra-v1
# * bedrock:ai21.j2-mid-v1
# * bedrock:ai21.jamba-instruct-v1:0
# * bedrock:cohere.command-light-text-v14
# * bedrock:cohere.command-text-v14
# * bedrock:cohere.command-r-v1:0
# * bedrock:cohere.command-r-plus-v1:0
# * bedrock:meta.llama2-13b-chat-v1
# * bedrock:meta.llama2-70b-chat-v1
# * bedrock:meta.llama3-8b-instruct-v1:0
# * bedrock:meta.llama3-70b-instruct-v1:0
# * bedrock:meta.llama3-1-8b-instruct-v1:0
# * bedrock:meta.llama3-1-70b-instruct-v1:0
# * bedrock:meta.llama3-1-405b-instruct-v1:0
# * bedrock:mistral.mistral-7b-instruct-v0:2
# ...

# %%
import pandas as pd
df = pd.read_csv('s3://fruit01/Fruit-Prices-2022.csv') 
df.head()
# Out:
#                         Fruit    Form  RetailPrice RetailPriceUnit  Yield  \
# 0                      Apples   Fresh       1.8541       per pound   0.90
# 1          Apples, applesauce  Canned       1.1705       per pound   1.00
# 2      Apples, ready-to-drink   Juice       0.8699        per pint   1.00
# 3  Apples, frozen concentrate   Juice       0.6086        per pint   1.00
# 4                    Apricots   Fresh       3.6162       per pound   0.93
#
#    CupEquivalentSize CupEquivalentUnit  CupEquivalentPrice
# 0             0.2425            pounds              0.4996
# 1             0.5401            pounds              0.6323
# 2             8.0000      fluid ounces              0.4349
# 3             8.0000      fluid ounces              0.3043
# 4             0.3638            pounds              1.4145

# %%
# %%ai gpt4
# what is in the {df} in {In[176]}
# Out:
# The given dataframe contains information about different types of fruits and their corresponding forms, retail prices, yields, and cup equivalent sizes and prices. Here's a breakdown of the columns:
#
# - **Fruit**: The name of the fruit.
# - **Form**: The form in which the fruit is sold, such as fresh, canned, juice, or frozen.
# - **RetailPrice**: The retail price of the fruit per unit.
# - **RetailPriceUnit**: The unit for the retail price, such as per pound or per pint.
# - **Yield**: The yield of the fruit, i.e., the edible proportion of the fruit.
# - **CupEquivalentSize**: The size of a cup equivalent of the fruit.
# - **CupEquivalentUnit**: The unit for the cup equivalent size, such as pounds or fluid ounces.
# - **CupEquivalentPrice**: The price for a cup equivalent of the fruit.
#
# ...

# %%
# %%ai gpt4 -f code
# calculate the RetailPrice growth rate for all Fruits from the {df} in {In[220]}
# display the result on chart
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
# Calculate RetailPrice Growth Rate
df['RetailPrice_GrowthRate'] = df['RetailPrice'].pct_change()

# Plot RetailPrice Growth Rate for each fruit
plt.figure(figsize=(10,6))
plt.plot(df['Fruit'], df['RetailPrice_GrowthRate'])
plt.title('Retail Price Growth Rate for each Fruit')
plt.xlabel('Fruit')
plt.ylabel('Retail Price Growth Rate')
plt.xticks(rotation=90)
plt.show()
'''
This code calculates the retail price growth rate for each fruit and displays the results in a line chart. The line chart provides a visual representation of how the retail price growth rate varies across different fruits.
'''
# Out:
# '\nThis code calculates the retail price growth rate for each fruit and displays the results in a line chart. The line chart provides a visual representation of how the retail price growth rate varies across different fruits.\n'

# %%
# %%ai gpt4 -f code
# calculate the highest RetailPrice for all Fruits from the {df} in {In[220]}
# display the result on chart
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
# Calculate Maximum RetailPrice for each Fruit
df_max_price = df.groupby('Fruit')['RetailPrice'].max()

# Plot Maximum RetailPrice for each Fruit
plt.figure(figsize=(10,6))
df_max_price.plot(kind='bar')
plt.title('Maximum Retail Price for each Fruit')
plt.xlabel('Fruit')
plt.ylabel('Maximum Retail Price')
plt.xticks(rotation=90)
plt.show()
'''
This code calculates the maximum retail price for each fruit and displays the results in a bar chart. The bar chart provides a visual representation of how the maximum retail price varies across different fruits.
'''
# Out:
# '\nThis code calculates the maximum retail price for each fruit and displays the results in a bar chart. The bar chart provides a visual representation of how the maximum retail price varies across different fruits.\n'

# %%
# %%ai gpt4 -f code
# calculate how much Yield per RetailPrice for all Fruits from the {df} in {In[220]}
# display the result on chart
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
# Plot Yield per RetailPrice for each Fruit
plt.figure(figsize=(10,6))
df.groupby('Fruit')['Yield_per_Price'].mean().sort_values().plot(kind='bar')
plt.title('Yield per Retail Price for each Fruit')
plt.xlabel('Fruit')
plt.ylabel('Yield per RetailPrice')
plt.xticks(rotation=90)
plt.show()
'''

This code plots the mean yield per retail price for each fruit using a bar chart. The 'Yield_per_Price' column is already present in the dataframe, so it doesn't need to be calculated again. The bar chart provides a visual representation of how the yield per retail price varies across different fruits.
'''
# Out:
# "\n\nThis code plots the mean yield per retail price for each fruit using a bar chart. The 'Yield_per_Price' column is already present in the dataframe, so it doesn't need to be calculated again. The bar chart provides a visual representation of how the yield per retail price varies across different fruits.\n"

# %%
# %%ai gpt4 -f code
# calculate the lowest RetailPrice for all Fruits from the {df} in {In[220]}
# display the result on chart
# Out:
# AI generated code inserted below &#11015;&#65039;

# %%
# Calculate the lowest RetailPrice for each Fruit
lowest_price = df.groupby('Fruit')['RetailPrice'].min()

# Plot the lowest RetailPrice for each Fruit
plt.figure(figsize=(10,6))
lowest_price.sort_values().plot(kind='bar')
plt.title('Lowest Retail Price for each Fruit')
plt.xlabel('Fruit')
plt.ylabel('Lowest RetailPrice')
plt.xticks(rotation=90)
plt.show()
'''

This code calculates the lowest retail price for each fruit and displays the results in a bar chart. The bar chart provides a visual representation of how the lowest retail price varies across different fruits.
'''
# Out:
# '\n\nThis code calculates the lowest retail price for each fruit and displays the results in a bar chart. The bar chart provides a visual representation of how the lowest retail price varies across different fruits.\n'
